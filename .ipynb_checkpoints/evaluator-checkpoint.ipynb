# %%
import numpy as np
import tensorflow as tf
from tensorflow.contrib.framework.python.ops.variables import get_or_create_global_step
from tensorflow.python.platform import tf_logging as logging
import inception_preprocessing
from inception_resnet_v2 import inception_resnet_v2, inception_resnet_v2_arg_scope
import os
import time
import subprocess

slim = tf.contrib.slim

# %%
# prepare label
place = ['house', 'lab', 'office']
# place = place[0:1]
num = ['4', '5', '6']
# num = ['1', '2', '3']
kind = ['left', 'right']

path = '../labels/'

label = np.array([])

for p in place:
    lab_list = os.listdir(path + p)
    for lab in lab_list:
        ali = lab
        if 'obj' in ali:
            ali = ali.replace('.npy', '')
            for k in kind:
                if k in ali:
                    if p == 'lab':
                        for n in range(1, 5):
                            if str(n) in ali:
                                if len(label) == 0:
                                    label = np.load(path + p + '/' + lab)
                                else:
                                    label = np.concatenate([label, np.load(path + p + '/' + lab)])
                    else:
                        for n in num:
                            if n in ali:
                                if len(label) == 0:
                                    label = np.load(path + p + '/' + lab)
                                else:
                                    label = np.concatenate([label, np.load(path + p + '/' + lab)])
label = label.astype(int)
# label = label[0:2]
print(len(label))
img_num = len(label)
# Out:
# 14992

# %%
import matplotlib.pyplot as plt

import tensorflow.contrib.slim.nets
vgg = tf.contrib.slim.nets.vgg

plt.style.use('ggplot')

log_dir = '../log'
log_eval = '../log_eval_test'
batch_size = 32
num_epochs = 1
checkpoint_file = tf.train.latest_checkpoint(log_dir)

#State the number of classes to predict:
obj = { 'free':0,
        'computer':1,
        'cellphone':2,
        'coin':3,
        'ruler':4,
        'thermos-bottle':5,
        'whiteboard-pen':6,
        'whiteboard-eraser':7,
        'pen':8,
        'cup':9,
        'remote-control-TV':10,
        'remote-control-AC':11,
        'switch':12,
        'windows':13,
        'fridge':14,
        'cupboard':15,
        'water-tap':16,
        'toy':17,
        'kettle':18,
        'bottle':19,
        'cookie':20,
        'book':21,
        'magnet':22,
        'lamp-switch':23}

num_classes = len(obj)
obj_by_value = {}

for key in obj.keys():
    obj_by_value[obj[key]] = key

#Create log_dir for evaluation information
if not os.path.exists(log_eval):
    os.mkdir(log_eval)

#Just construct the graph from scratch again
with tf.Graph().as_default() as graph:
    tf.logging.set_verbosity(tf.logging.INFO)

    #Create some information about the training steps
    num_batches_per_epoch = int(img_num / batch_size)
    num_steps_per_epoch = num_batches_per_epoch
    
    # prepare image FIFOQueue
    height = 224
    width = 224
    num_threads = 4

    image_names = tf.train.match_filenames_once('../frames/test/*/*/*hand/Image*.png')
    image_queue = tf.train.string_input_producer(image_names, shuffle = False)

    image_reader = tf.WholeFileReader()
    _, image_value = image_reader.read(image_queue)

    image_tf = tf.image.decode_png(image_value, channels = 3)
    image_tf = tf.image.resize_images(image_tf, [height, width])
    image_tf.set_shape((height, width, 3))
    image_tf = tf.subtract(tf.multiply(2.0, tf.divide(image_tf, 255.0)), 1.0)
#     image_tf = inception_preprocessing.preprocess_image(image_tf, height, width, is_training = True)

    # prepare label FIFOQueue
    label_tf = tf.convert_to_tensor(label, dtype = tf.int32)
    label_queue = tf.train.slice_input_producer([label_tf], shuffle = False)
    
    # prepare original image for visualize
    raw_image = tf.image.decode_png(image_value, channels = 3)
    raw_image = tf.expand_dims(raw_image, 0)
    raw_image = tf.image.resize_nearest_neighbor(raw_image, [height, width])
    raw_image = tf.squeeze(raw_image)
    
    # creating a batch of images and labels
    batch_image, batch_raw_image, batch_label = tf.train.batch([[image_tf], [raw_image], label_queue], 
                                                                batch_size = batch_size, 
                                                                num_threads = num_threads,
                                                                capacity = num_threads * batch_size,
                                                                enqueue_many = True,
                                                                allow_smaller_final_batch = True)
    
    
    #Now create the inference model but set is_training=False
    logits, end_points = vgg.vgg_16(batch_image, 
                                    num_classes = num_classes,
                                    is_training = False)

    #get all the variables to restore from the checkpoint file and create the saver function to restore
    variables_to_restore = slim.get_variables_to_restore()
    saver = tf.train.Saver(variables_to_restore)
    def restore_fn(sess):
        return saver.restore(sess, checkpoint_file)

    #Just define the metrics to track without the loss or whatsoever
    probabilities = tf.nn.softmax(logits)
    predictions = tf.argmax(probabilities, 1)
    accuracy, accuracy_update = tf.contrib.metrics.streaming_accuracy(predictions, batch_label)
    metrics_op = tf.group(accuracy_update, probabilities)

    #Create the global step and an increment op for monitoring
    global_step = get_or_create_global_step()
    global_step_op = tf.assign(global_step, global_step + 1) #no apply_gradient method so manually increasing the global_step

    #Create a evaluation step function
    def eval_step(sess, metrics_op, global_step):
        start_time = time.time()
        _, global_step_count, accuracy_value, prediction = sess.run([metrics_op, global_step_op, accuracy, predictions])
        time_elapsed = time.time() - start_time

        #Log some information
        logging.info('Global Step %s: Streaming Accuracy: %.4f (%.2f sec/step)', global_step_count, accuracy_value, time_elapsed)
        if global_step_count % 10 == 0:
            for i in range(batch_size):
                logging.info('Current Streaming Predictions: %d', prediction[i])
        return accuracy_value

    #Define some scalar quantities to monitor
    tf.summary.scalar('Validation_Accuracy', accuracy)
    my_summary_op = tf.summary.merge_all()

    #Get your supervisor
    sv = tf.train.Supervisor(logdir = log_eval, summary_op = None, saver = None, init_fn = restore_fn)

    #Now we are ready to run in one session
    with sv.managed_session() as sess:
        '''
        accuracry section
        '''
        for step in range(num_steps_per_epoch * num_epochs):
            global_step_counts = sess.run(sv.global_step)
            #Compute summaries every 10 steps and continue evaluating
            if step % 10 == 0:
                eval_step(sess, metrics_op = metrics_op, global_step = sv.global_step)
                summaries = sess.run(my_summary_op)
                sv.summary_computed(sess, summaries)

            #Otherwise just run as per normal
            else:
                eval_step(sess, metrics_op = metrics_op, global_step = sv.global_step)

        #At the end of all the evaluation, show the final accuracy
        logging.info('Final Streaming Accuracy: %.4f', sess.run(accuracy))
    
        '''
        Now we want to visualize the last batch's images just to see what our model has predicted
        
        '''
#         pred_raw_image, pred_label, predicts = sess.run([batch_raw_image, batch_label, predictions])
#         for i in range(batch_size):
#             image, label, predict = pred_raw_image[i], pred_label[i], predicts[i]
#             prediction_name, label_name = obj_by_value[int(predict)], obj_by_value[int(label)]
#             text = 'Prediction: %s \n Ground Truth: %s' %(prediction_name, label_name)
#             print(text)
        '''
        test label and image are right
        
        '''
#         for step in range(200):
#             pred_raw_image, pred_label = sess.run([batch_raw_image, batch_label])
#             for i in range(batch_size):
#                 img_plot = plt.imshow(pred_raw_image[i])

#                 #Set up the plot and hide axes
#                 plt.title(obj_by_value[int(pred_label[i])])
#                 img_plot.axes.get_yaxis().set_ticks([])
#                 img_plot.axes.get_xaxis().set_ticks([])
#                 plt.show()

#         logging.info('Model evaluation has completed! Visit TensorBoard for more information regarding your evaluation.')
# Out:
# INFO:tensorflow:Restoring parameters from ../log\model.ckpt-0
# INFO:tensorflow:Starting standard services.
# INFO:tensorflow:Starting queue runners.
# INFO:tensorflow:global_step/sec: 0
# INFO:tensorflow:Global Step 1: Streaming Accuracy: 0.0000 (0.36 sec/step)
# INFO:tensorflow:Global Step 2: Streaming Accuracy: 1.0000 (0.42 sec/step)
# INFO:tensorflow:Global Step 3: Streaming Accuracy: 0.9375 (0.35 sec/step)
# INFO:tensorflow:Global Step 4: Streaming Accuracy: 0.9583 (0.37 sec/step)
# INFO:tensorflow:Global Step 5: Streaming Accuracy: 0.9062 (0.37 sec/step)
# INFO:tensorflow:Global Step 6: Streaming Accuracy: 0.8125 (0.38 sec/step)
# INFO:tensorflow:Global Step 7: Streaming Accuracy: 0.7552 (0.38 sec/step)
# INFO:tensorflow:Global Step 8: Streaming Accuracy: 0.7098 (0.38 sec/step)
# INFO:tensorflow:Global Step 9: Streaming Accuracy: 0.7461 (0.37 sec/step)
# INFO:tensorflow:Global Step 10: Streaming Accuracy: 0.7674 (0.37 sec/step)
# INFO:tensorflow:Current Streaming Predictions: 18
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 18
# INFO:tensorflow:Current Streaming Predictions: 18
# INFO:tensorflow:Current Streaming Predictions: 18
# INFO:tensorflow:Current Streaming Predictions: 18
# INFO:tensorflow:Current Streaming Predictions: 18
# INFO:tensorflow:Current Streaming Predictions: 18
# INFO:tensorflow:Current Streaming Predictions: 18
# INFO:tensorflow:Current Streaming Predictions: 18
# INFO:tensorflow:Current Streaming Predictions: 18
# INFO:tensorflow:Current Streaming Predictions: 18
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 18
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Global Step 11: Streaming Accuracy: 0.7812 (0.35 sec/step)
# INFO:tensorflow:Global Step 12: Streaming Accuracy: 0.8011 (0.34 sec/step)
# INFO:tensorflow:Global Step 13: Streaming Accuracy: 0.8125 (0.38 sec/step)
# INFO:tensorflow:Global Step 14: Streaming Accuracy: 0.8245 (0.37 sec/step)
# INFO:tensorflow:Global Step 15: Streaming Accuracy: 0.8147 (0.39 sec/step)
# INFO:tensorflow:Global Step 16: Streaming Accuracy: 0.7667 (0.41 sec/step)
# INFO:tensorflow:Global Step 17: Streaming Accuracy: 0.7207 (0.46 sec/step)
# INFO:tensorflow:Global Step 18: Streaming Accuracy: 0.6912 (0.36 sec/step)
# INFO:tensorflow:Global Step 19: Streaming Accuracy: 0.7014 (0.38 sec/step)
# INFO:tensorflow:Global Step 20: Streaming Accuracy: 0.6974 (0.37 sec/step)
# INFO:tensorflow:Current Streaming Predictions: 19
# INFO:tensorflow:Current Streaming Predictions: 19
# INFO:tensorflow:Current Streaming Predictions: 19
# INFO:tensorflow:Current Streaming Predictions: 19
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 19
# INFO:tensorflow:Current Streaming Predictions: 19
# INFO:tensorflow:Current Streaming Predictions: 19
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 19
# INFO:tensorflow:Current Streaming Predictions: 18
# INFO:tensorflow:Current Streaming Predictions: 18
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:
# INFO:tensorflow:Global Step 129: Streaming Accuracy: 0.7478 (0.39 sec/step)
# INFO:tensorflow:Global Step 130: Streaming Accuracy: 0.7473 (0.44 sec/step)
# INFO:tensorflow:Current Streaming Predictions: 19
# INFO:tensorflow:Current Streaming Predictions: 19
# INFO:tensorflow:Current Streaming Predictions: 19
# INFO:tensorflow:Current Streaming Predictions: 19
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 19
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Global Step 131: Streaming Accuracy: 0.7464 (0.43 sec/step)
# INFO:tensorflow:Global Step 132: Streaming Accuracy: 0.7483 (0.44 sec/step)
# INFO:tensorflow:Global Step 133: Streaming Accuracy: 0.7453 (0.39 sec/step)
# INFO:tensorflow:Global Step 134: Streaming Accuracy: 0.7465 (0.41 sec/step)
# INFO:tensorflow:Global Step 135: Streaming Accuracy: 0.7484 (0.42 sec/step)
# INFO:tensorflow:Global Step 136: Streaming Accuracy: 0.7449 (0.41 sec/step)
# INFO:tensorflow:Global Step 137: Streaming Accuracy: 0.7468 (0.40 sec/step)
# INFO:tensorflow:Global Step 138: Streaming Accuracy: 0.7486 (0.39 sec/step)
# INFO:tensorflow:Global Step 139: Streaming Accuracy: 0.7466 (0.43 sec/step)
# INFO:tensorflow:Global Step 140: Streaming Accuracy: 0.7464 (0.37 sec/step)
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Global Step 141: Streaming Accuracy: 0.7482 (0.33 sec/step)
# INFO:tensorflow:Global Step 142: Streaming Accuracy: 0.7478 (0.39 sec/step)
# INFO:tensorflow:Global Step 143: Streaming Accuracy: 0.7487 (0.34 sec/step)
# INFO:tensorflow:Global Step 144: Streaming Accuracy: 0.7472 (0.41 sec/step)
# INFO:tensorflow:Global Step 145: Streaming Accuracy: 0.7431 (0.39 sec/step)
# INFO:tensorflow:Global Step 146: Streaming Accuracy: 0.7379 (0.39 sec/step)
# INFO:tensorflow:Global Step 147: Streaming Accuracy: 0.7329 (0.37 sec/step)
# INFO:tensorflow:Global Step 148: Streaming Accuracy: 0.7298 (0.38 sec/step)
# INFO:tensorflow:Global Step 149: Streaming Accuracy: 0.7295 (0.41 sec/step)
# INFO:tensorflow:Global Step 150: Streaming Accuracy: 0.7261 (0.42 sec/step)
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 9
# INFO:tensorflow:Current Streaming Predictions: 9
# INFO:tensorflow:Current Streaming Predictions: 9
# INFO:tensorflow:Current Streaming Predictions: 9
# INFO:tensorflow:Current Streaming Predictions: 9
# INFO:tensorflow:Current Streaming Predictions: 9
# INFO:tensorflow:Current Streaming Predictions: 9
# INFO:tensorflow:Current Streaming Predictions: 9
# INFO:tensorflow:Current Streaming Predictions: 9
# INFO:tensorflow:Current Streaming Predictions: 9
# INFO:tensorflow:Current Streaming Predictions: 9
# INFO:tensorflow:Current Streaming Predictions: 9
# INFO:tensorflow:Current Streaming Predictions: 9
# INFO:tensorflow:Current Streaming Predictions: 9
# INFO:tensorflow:Current Streaming Predictions: 9
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Global Step 151: Streaming Accuracy: 0.7256 (0.38 sec/step)
# INFO:tensorflow:Global Step 152: Streaming Accuracy: 0.7274 (0.37 sec/step)
# INFO:tensorflow:Global Step 153: Streaming Accuracy: 0.7292 (0.38 sec/step)
# INFO:tensorflow:Global Step 154: Streaming Accuracy: 0.7310 (0.37 sec/step)
# INFO:tensorflow:Global Step 155: Streaming Accuracy: 0.7315 (0.36 sec/step)
# INFO:tensorflow:Global Step 156: Streaming Accuracy: 0.7321 (0.38 sec/step)
# INFO:tensorflow:Global Step 157: Streaming Accuracy: 0.7292 (0.38 sec/step)
# INFO:tensorflow:Global Step 158: Streaming Accuracy: 0.7269 (0.40 sec/step)
# INFO:tensorflow:Global Step 159: Streaming Accuracy: 0.7280 (0.40 sec/step)
# INFO:tensorflow:Global Step 160: Streaming Accuracy: 0.7288 (0.38 sec/step)
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 9
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 9
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 9
# INFO:tensorflow:Current Streaming Predictions: 9
# INFO:tensorflow:Current Streaming Predictions: 9
# INFO:tensorflow:Current Streaming Predictions: 9
# INFO:tensorflow:Current Streaming Predictions: 9
# INFO:tensorflow:Current Streaming Predictions: 9
# INFO:tensorflow:Current Streaming Predictions: 9
# INFO:tensorflow:Current Streaming Predictions: 9
# INFO:tensorflow:Current Streaming Predictions: 9
# INFO:tensorflow:Current Streaming Predictions: 9
# INFO:tensorflow:Current Streaming Predictions: 9
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 9
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 9
# INFO:tensorflow:Current Streaming Predictions: 9
# INFO:tensorflow:Current Streaming Predictions: 9
# INFO:tensorflow:Global Step 161: Streaming Accuracy: 0.7275 (0.36 sec/step)
# INFO:tensorflow:Global Step 162: Streaming Accuracy: 0.7250 (0.39 sec/step)
# INFO:tensorflow:Global Step 163: Streaming Accuracy: 0.7216 (0.40 sec/step)
# INFO:tensorflow:Global Step 164: Streaming Accuracy: 0.7189 (0.38 sec/step)
# INFO:tensorflow:Global Step 165: Streaming Accuracy: 0.7151 (0.41 sec/step)
# INFO:tensorflow:Global Step 166: Streaming Accuracy: 0.7110 (0.42 sec/step)
# INFO:tensorflow:Global Step 167: Streaming Accuracy: 0.7084 (0.42 sec/step)
# INFO:tensorflow:Global Step 168: Streaming Accuracy: 0.7055 (0.40 sec/step)
# INFO:tensorflow:Global Step 169: Streaming Accuracy: 0.7031 (0.40 sec/step)
# INFO:tensorflow:Global Step 170: Streaming Accuracy: 0.6999 (0.40 sec/step)
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Global Step 171: Streaming Accuracy: 0.7004 (0.36 sec/step)
# INFO:tensorflow:Global Step 172: Streaming Accuracy: 0.7008 (0.39 sec/step)
# INFO:tensorflow:Global Step 173: Streaming Accuracy: 0.7026 (0.40 sec/step)
# INFO:tensorflow:Global Step 174: Streaming Accuracy: 0.7020 (0.40 sec/step)
# INFO:tensorflow:Global Step 175: Streaming Accuracy: 0.7015 (0.41 sec/step)
# INFO:tensorflow:Global Step 176: Streaming Accuracy: 0.7032 (0.40 sec/step)
# INFO:tensorflow:Global Step 177: Streaming Accuracy: 0.7040 (0.43 sec/step)
# INFO:tensorflow:Global Step 178: Streaming Accuracy: 0.7036 (0.45 sec/step)
# INFO:tensorflow:Global Step 179: Streaming Accuracy: 0.7033 (0.36 sec/step)
# INFO:tensorflow:Global Step 180: Streaming Accuracy: 0.7018 (0.40 sec/step)
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Global Step 181: Streaming Accuracy: 0.7012 (0.33 sec/step)
# INFO:tensorflow:Global Step 182: Streaming Accuracy: 0.6991 (0.40 sec/step)
# INFO:tensorflow:Global Step 183: Streaming Accuracy: 0.6952 (0.36 sec/step)
# INFO:tensorflow:Global Step 184: Streaming Accuracy: 0.6955 (0.38 sec/step)
# INFO:tensorflow:Global Step 185: Streaming Accuracy: 0.6965 (0.40 sec/step)
# INFO:tensorflow:Global Step 186: Streaming Accuracy: 0.6944 (0.38 sec/step)
# INFO:tensorflow:Global Step 187: Streaming Accuracy: 0.6912 (0.40 sec/step)
# INFO:tensorflow:Global Step 188: Streaming Accuracy: 0.6875 (0.37 sec/step)
# INFO:tensorflow:Global Step 189: Streaming Accuracy: 0.6838 (0.40 sec/step)
# INFO:tensorflow:Global Step 190: Streaming Accuracy: 0.6802 (0.39 sec/step)
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 10
# INFO:tensorflow:Current Streaming Predictions: 10
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 10
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 10
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Global Step 191: Streaming Accuracy: 0.6785 (0.36 sec/step)
# INFO:tensorflow:Global Step 192: Streaming Accuracy: 0.6801 (0.37 sec/step)
# INFO:tensorflow:Global Step 193: Streaming Accuracy: 0.6813 (0.35 sec/step)
# INFO:tensorflow:Global Step 194: Streaming Accuracy: 0.6818 (0.35 sec/step)
# INFO:tensorflow:Global Step 195: Streaming Accuracy: 0.6814 (0.38 sec/step)
# INFO:tensorflow:Global Step 196: Streaming Accuracy: 0.6814 (0.40 sec/step)
# INFO:tensorflow:Global Step 197: Streaming Accuracy: 0.6830 (0.39 sec/step)
# INFO:tensorflow:Global Step 198: Streaming Accuracy: 0.6829 (0.37 sec/step)
# INFO:tensorflow:Global Step 199: Streaming Accuracy: 0.6821 (0.37 sec/step)
# INFO:tensorflow:Global Step 200: Streaming Accuracy: 0.6817 (0.38 sec/step)
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 8
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 3
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 3
# INFO:tensorflow:Current Streaming Predictions: 3
# INFO:tensorflow:Current Streaming Predictions: 3
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 3
# INFO:tensorflow:Current Streaming Predictions: 3
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 3
# INFO:tensorflow:Current Streaming Predictions: 3
# INFO:tensorflow:Current Streaming Predictions: 3
# INFO:tensorflow:Current Streaming Predictions: 3
# INFO:tensorflow:Current Streaming Predictions: 3
# INFO:tensorflow:Current Streaming Predictions: 3
# INFO:tensorflow:Current Streaming Predictions: 3
# INFO:tensorflow:Current Streaming Predictions: 3
# INFO:tensorflow:Global Step 201: Streaming Accuracy: 0.6816 (0.34 sec/step)
# INFO:tensorflow:Global Step 202: Streaming Accuracy: 0.6814 (0.36 sec/step)
# INFO:tensorflow:Global Step 203: Streaming Accuracy: 0.6791 (0.38 sec/step)
# INFO:tensorflow:Global Step 204: Streaming Accuracy: 0.6781 (0.40 sec/step)
# INFO:tensorflow:Global Step 205: Streaming Accuracy: 0.6791 (0.42 sec/step)
# INFO:tensorflow:Global Step 206: Streaming Accuracy: 0.6797 (0.39 sec/step)
# INFO:tensorflow:Global Step 207: Streaming Accuracy: 0.6787 (0.38 sec/step)
# INFO:tensorflow:Global Step 208: Streaming Accuracy: 0.6792 (0.33 sec/step)
# INFO:tensorflow:Global Step 209: Streaming Accuracy: 0.6783 (0.36 sec/step)
# INFO:tensorflow:Global Step 210: Streaming Accuracy: 0.6790 (0.37 sec/step)
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# ...
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Global Step 401: Streaming Accuracy: 0.6002 (0.36 sec/step)
# INFO:tensorflow:Global Step 402: Streaming Accuracy: 0.5988 (0.39 sec/step)
# INFO:tensorflow:Global Step 403: Streaming Accuracy: 0.5983 (0.43 sec/step)
# INFO:tensorflow:Global Step 404: Streaming Accuracy: 0.5989 (0.42 sec/step)
# INFO:tensorflow:Global Step 405: Streaming Accuracy: 0.5996 (0.41 sec/step)
# INFO:tensorflow:Global Step 406: Streaming Accuracy: 0.5990 (0.39 sec/step)
# INFO:tensorflow:Global Step 407: Streaming Accuracy: 0.5984 (0.40 sec/step)
# INFO:tensorflow:Global Step 408: Streaming Accuracy: 0.5987 (0.39 sec/step)
# INFO:tensorflow:Global Step 409: Streaming Accuracy: 0.5996 (0.41 sec/step)
# INFO:tensorflow:Global Step 410: Streaming Accuracy: 0.6002 (0.38 sec/step)
# INFO:tensorflow:Current Streaming Predictions: 1
# INFO:tensorflow:Current Streaming Predictions: 1
# INFO:tensorflow:Current Streaming Predictions: 1
# INFO:tensorflow:Current Streaming Predictions: 1
# INFO:tensorflow:Current Streaming Predictions: 1
# INFO:tensorflow:Current Streaming Predictions: 1
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 1
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 1
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Global Step 411: Streaming Accuracy: 0.5994 (0.39 sec/step)
# INFO:tensorflow:Global Step 412: Streaming Accuracy: 0.5983 (0.43 sec/step)
# INFO:tensorflow:Global Step 413: Streaming Accuracy: 0.5981 (0.35 sec/step)
# INFO:tensorflow:Global Step 414: Streaming Accuracy: 0.5977 (0.35 sec/step)
# INFO:tensorflow:Global Step 415: Streaming Accuracy: 0.5974 (0.34 sec/step)
# INFO:tensorflow:Global Step 416: Streaming Accuracy: 0.5959 (0.40 sec/step)
# INFO:tensorflow:Global Step 417: Streaming Accuracy: 0.5965 (0.35 sec/step)
# INFO:tensorflow:Global Step 418: Streaming Accuracy: 0.5962 (0.38 sec/step)
# INFO:tensorflow:Global Step 419: Streaming Accuracy: 0.5956 (0.35 sec/step)
# INFO:tensorflow:Global Step 420: Streaming Accuracy: 0.5942 (0.34 sec/step)
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Global Step 421: Streaming Accuracy: 0.5928 (0.30 sec/step)
# INFO:tensorflow:Global Step 422: Streaming Accuracy: 0.5933 (0.39 sec/step)
# INFO:tensorflow:Global Step 423: Streaming Accuracy: 0.5943 (0.37 sec/step)
# INFO:tensorflow:Global Step 424: Streaming Accuracy: 0.5945 (0.39 sec/step)
# INFO:tensorflow:Global Step 425: Streaming Accuracy: 0.5943 (0.40 sec/step)
# INFO:tensorflow:Global Step 426: Streaming Accuracy: 0.5943 (0.37 sec/step)
# INFO:tensorflow:Global Step 427: Streaming Accuracy: 0.5953 (0.37 sec/step)
# INFO:tensorflow:Global Step 428: Streaming Accuracy: 0.5953 (0.37 sec/step)
# INFO:tensorflow:Global Step 429: Streaming Accuracy: 0.5952 (0.33 sec/step)
# INFO:tensorflow:Global Step 430: Streaming Accuracy: 0.5938 (0.37 sec/step)
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Global Step 431: Streaming Accuracy: 0.5941 (0.33 sec/step)
# INFO:tensorflow:Global Step 432: Streaming Accuracy: 0.5951 (0.35 sec/step)
# INFO:tensorflow:Global Step 433: Streaming Accuracy: 0.5950 (0.39 sec/step)
# INFO:tensorflow:Global Step 434: Streaming Accuracy: 0.5940 (0.39 sec/step)
# INFO:tensorflow:Global Step 435: Streaming Accuracy: 0.5934 (0.37 sec/step)
# INFO:tensorflow:Global Step 436: Streaming Accuracy: 0.5926 (0.37 sec/step)
# INFO:tensorflow:Global Step 437: Streaming Accuracy: 0.5935 (0.36 sec/step)
# INFO:tensorflow:Global Step 438: Streaming Accuracy: 0.5940 (0.38 sec/step)
# INFO:tensorflow:Global Step 439: Streaming Accuracy: 0.5935 (0.37 sec/step)
# INFO:tensorflow:Global Step 440: Streaming Accuracy: 0.5931 (0.37 sec/step)
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 22
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 18
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Global Step 441: Streaming Accuracy: 0.5934 (0.35 sec/step)
# INFO:tensorflow:Global Step 442: Streaming Accuracy: 0.5923 (0.35 sec/step)
# INFO:tensorflow:Global Step 443: Streaming Accuracy: 0.5920 (0.39 sec/step)
# INFO:tensorflow:Global Step 444: Streaming Accuracy: 0.5918 (0.37 sec/step)
# INFO:tensorflow:Global Step 445: Streaming Accuracy: 0.5908 (0.35 sec/step)
# INFO:tensorflow:Global Step 446: Streaming Accuracy: 0.5900 (0.37 sec/step)
# INFO:tensorflow:Global Step 447: Streaming Accuracy: 0.5902 (0.35 sec/step)
# INFO:tensorflow:Global Step 448: Streaming Accuracy: 0.5900 (0.37 sec/step)
# INFO:tensorflow:Global Step 449: Streaming Accuracy: 0.5904 (0.35 sec/step)
# INFO:tensorflow:Global Step 450: Streaming Accuracy: 0.5913 (0.36 sec/step)
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 22
# INFO:tensorflow:Current Streaming Predictions: 22
# INFO:tensorflow:Current Streaming Predictions: 22
# INFO:tensorflow:Global Step 451: Streaming Accuracy: 0.5920 (0.32 sec/step)
# INFO:tensorflow:Global Step 452: Streaming Accuracy: 0.5916 (0.33 sec/step)
# INFO:tensorflow:Global Step 453: Streaming Accuracy: 0.5913 (0.38 sec/step)
# INFO:tensorflow:Global Step 454: Streaming Accuracy: 0.5912 (0.37 sec/step)
# INFO:tensorflow:Global Step 455: Streaming Accuracy: 0.5902 (0.36 sec/step)
# INFO:tensorflow:Global Step 456: Streaming Accuracy: 0.5891 (0.37 sec/step)
# INFO:tensorflow:Global Step 457: Streaming Accuracy: 0.5890 (0.39 sec/step)
# INFO:tensorflow:Global Step 458: Streaming Accuracy: 0.5899 (0.40 sec/step)
# INFO:tensorflow:Global Step 459: Streaming Accuracy: 0.5907 (0.37 sec/step)
# INFO:tensorflow:Global Step 460: Streaming Accuracy: 0.5912 (0.38 sec/step)
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 5
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 5
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Current Streaming Predictions: 0
# INFO:tensorflow:Global Step 461: Streaming Accuracy: 0.5915 (0.38 sec/step)
# INFO:tensorflow:Global Step 462: Streaming Accuracy: 0.5904 (0.39 sec/step)
# INFO:tensorflow:Global Step 463: Streaming Accuracy: 0.5909 (0.42 sec/step)
# INFO:tensorflow:Global Step 464: Streaming Accuracy: 0.5900 (0.39 sec/step)
# INFO:tensorflow:Global Step 465: Streaming Accuracy: 0.5898 (0.34 sec/step)
# INFO:tensorflow:Global Step 466: Streaming Accuracy: 0.5890 (0.40 sec/step)
# INFO:tensorflow:Global Step 467: Streaming Accuracy: 0.5886 (0.35 sec/step)
# INFO:tensorflow:Global Step 468: Streaming Accuracy: 0.5887 (0.37 sec/step)
# INFO:tensorflow:Final Streaming Accuracy: 0.5896

# %%
import matplotlib.pyplot as plt

'''Inception-Resnet-v2 model testing'''

plt.style.use('ggplot')

log_dir = '../log'
log_eval = '../log_eval_test'
batch_size = 32
num_epochs = 1
checkpoint_file = tf.train.latest_checkpoint(log_dir)

#State the number of classes to predict:
obj = { 'free':0,
        'computer':1,
        'cellphone':2,
        'coin':3,
        'ruler':4,
        'thermos-bottle':5,
        'whiteboard-pen':6,
        'whiteboard-eraser':7,
        'pen':8,
        'cup':9,
        'remote-control-TV':10,
        'remote-control-AC':11,
        'switch':12,
        'windows':13,
        'fridge':14,
        'cupboard':15,
        'water-tap':16,
        'toy':17,
        'kettle':18,
        'bottle':19,
        'cookie':20,
        'book':21,
        'magnet':22,
        'lamp-switch':23}

num_classes = len(obj)
obj_by_value = {}

for key in obj.keys():
    obj_by_value[obj[key]] = key

#Create log_dir for evaluation information
if not os.path.exists(log_eval):
    os.mkdir(log_eval)

#Just construct the graph from scratch again
with tf.Graph().as_default() as graph:
    tf.logging.set_verbosity(tf.logging.INFO)

    #Create some information about the training steps
    num_batches_per_epoch = int(img_num / batch_size)
    num_steps_per_epoch = num_batches_per_epoch
    
    # prepare image FIFOQueue
    height = 299
    width = 299
    num_threads = 4

    image_names = tf.train.match_filenames_once('../frames/test/*/*/*hand/Image*.png')
    image_queue = tf.train.string_input_producer(image_names, shuffle = False)

    image_reader = tf.WholeFileReader()
    _, image_value = image_reader.read(image_queue)

    image_tf = tf.image.decode_png(image_value, channels = 3)
    image_tf = tf.image.resize_images(image_tf, [height, width])
    image_tf.set_shape((height, width, 3))
    image_tf = tf.subtract(tf.multiply(2.0, tf.divide(image_tf, 255.0)), 0.5)
#     image_tf = inception_preprocessing.preprocess_image(image_tf, height, width, is_training = True)

    # prepare label FIFOQueue
    label_tf = tf.convert_to_tensor(label, dtype = tf.int32)
    label_queue = tf.train.slice_input_producer([label_tf], shuffle = False)
    
    # prepare original image for visualize
    raw_image = tf.image.decode_png(image_value, channels = 3)
    raw_image = tf.expand_dims(raw_image, 0)
    raw_image = tf.image.resize_nearest_neighbor(raw_image, [height, width])
    raw_image = tf.squeeze(raw_image)
    
    # creating a batch of images and labels
    batch_image, batch_raw_image, batch_label = tf.train.batch([[image_tf], [raw_image], label_queue], 
                                                                batch_size = batch_size, 
                                                                num_threads = num_threads,
                                                                enqueue_many = True,
                                                                allow_smaller_final_batch = True)
    
    
    #Now create the inference model but set is_training=False
    with slim.arg_scope(inception_resnet_v2_arg_scope()):
        logits, end_points = inception_resnet_v2(batch_image, num_classes = num_classes, is_training = True)
    
    #get all the variables to restore from the checkpoint file and create the saver function to restore
    variables_to_restore = slim.get_variables_to_restore()
    saver = tf.train.Saver(variables_to_restore)
    def restore_fn(sess):
        return saver.restore(sess, checkpoint_file)

    #Just define the metrics to track without the loss or whatsoever
    predictions = tf.argmax(end_points['Predictions'], 1)
    accuracy, accuracy_update = tf.contrib.metrics.streaming_accuracy(predictions, batch_label)
    metrics_op = tf.group(accuracy_update)

    #Create the global step and an increment op for monitoring
    global_step = get_or_create_global_step()
    global_step_op = tf.assign(global_step, global_step + 1) #no apply_gradient method so manually increasing the global_step

    #Create a evaluation step function
    def eval_step(sess, metrics_op, global_step):
        start_time = time.time()
        _, global_step_count, accuracy_value, prediction = sess.run([metrics_op, global_step_op, accuracy, predictions])
        time_elapsed = time.time() - start_time

        #Log some information
        logging.info('Global Step %s: Streaming Accuracy: %.4f (%.2f sec/step)', global_step_count, accuracy_value, time_elapsed)
        if global_step % 10 == 0:
            for i in range(batch_size):
                logging.info('Current Streaming Predictions: %d', prediction[i])
        return accuracy_value

    #Define some scalar quantities to monitor
    tf.summary.scalar('Validation_Accuracy', accuracy)
    my_summary_op = tf.summary.merge_all()

    #Get your supervisor
    sv = tf.train.Supervisor(logdir = log_eval, summary_op = None, saver = None, init_fn = restore_fn)

    #Now we are ready to run in one session
    with sv.managed_session() as sess:
        '''
        accuracry section
        '''
#         for step in range(num_steps_per_epoch * num_epochs):
#             sess.run(sv.global_step)
#             #Compute summaries every 10 steps and continue evaluating
#             if step % 10 == 0:
#                 eval_step(sess, metrics_op = metrics_op, global_step = sv.global_step)
#                 summaries = sess.run(my_summary_op)
#                 sv.summary_computed(sess, summaries)

#             #Otherwise just run as per normal
#             else:
#                 eval_step(sess, metrics_op = metrics_op, global_step = sv.global_step)

#         #At the end of all the evaluation, show the final accuracy
#         logging.info('Final Streaming Accuracy: %.4f', sess.run(accuracy))
    
        '''
        Now we want to visualize the last batch's images just to see what our model has predicted
        
        '''
#         pred_raw_image, pred_label, predicts = sess.run([batch_raw_image, batch_label, predictions])
#         for i in range(batch_size):
#             image, label, predict = pred_raw_image[i], pred_label[i], predicts[i]
#             prediction_name, label_name = obj_by_value[int(predict)], obj_by_value[int(label)]
#             text = 'Prediction: %s \n Ground Truth: %s' %(prediction_name, label_name)
#             print(text)
        '''
        test label and image are right
        
        '''
#         for step in range(200):
#             pred_raw_image, pred_label = sess.run([batch_raw_image, batch_label])
#             for i in range(batch_size):
#                 img_plot = plt.imshow(pred_raw_image[i])

#                 #Set up the plot and hide axes
#                 plt.title(obj_by_value[int(pred_label[i])])
#                 img_plot.axes.get_yaxis().set_ticks([])
#                 img_plot.axes.get_xaxis().set_ticks([])
#                 plt.show()

#         logging.info('Model evaluation has completed! Visit TensorBoard for more information regarding your evaluation.')
# Out:
# label data loaded, and the number of labels is: 4056
# num_batches_per_epoch: 253
